# %%
import pandas as pd

# %%
#opening the csv file and reading it, assigning the contents to the variable file

file = open("gdp_europe.csv").read()

# %%
print(file[:400])
# Out:
# country,gdpPercap_1952,gdpPercap_1957,gdpPercap_1962,gdpPercap_1967,gdpPercap_1972,gdpPercap_1977,gdpPercap_1982,gdpPercap_1987,gdpPercap_1992,gdpPercap_1997,gdpPercap_2002,gdpPercap_2007
# Albania,1601.056136,1942.284244,2312.888958,2760.196931,3313.422188,3533.00391,3630.880722,3738.932735,2497.437901,3193.054604,4604.211737,5937.029526
# Austria,6137.076492,8842.59803,10750.72111,12834.6024,16661.6

# %%
#Using pandas to open a dataframe from the contents of the csv file gdp_africa.csv. 
#Saving the contents of the csv file to variable df

df = pd.read_csv("gdp_europe.csv", index_col=0)

# %%
print(df)
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Albania                    1601.056136     1942.284244     2312.888958  \
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
#printing the first three rows of the dataframe

df.head(3)
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967
# country
# Albania     1601.056136     1942.284244     2312.888958     2760.196931  \
# Austria     6137.076492     8842.598030    10750.721110    12834.602400
# Belgium     8343.105127     9714.960623    10991.206760    13149.041190
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987
# country
# Albania     3313.422188      3533.00391     3630.880722     3738.932735  \
# Austria    16661.625600     19749.42230    21597.083620    23687.826070
# Belgium    16672.143560     19117.97448    20979.845890    22525.563080
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Albania     2497.437901     3193.054604     4604.211737     5937.029526
# Austria    27042.018680    29095.920660    32417.607690    36126.492700
# Belgium    25575.570690    27561.196630    30485.883750    33692.605080

# %%
#Getting summary info about the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, Albania to United Kingdom
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gdpPercap_1952  30 non-null     float64
#  1   gdpPercap_1957  30 non-null     float64
#  2   gdpPercap_1962  30 non-null     float64
#  3   gdpPercap_1967  30 non-null     float64
#  4   gdpPercap_1972  30 non-null     float64
#  5   gdpPercap_1977  30 non-null     float64
#  6   gdpPercap_1982  30 non-null     float64
#  7   gdpPercap_1987  30 non-null     float64
#  8   gdpPercap_1992  30 non-null     float64
#  9   gdpPercap_1997  30 non-null     float64
#  10  gdpPercap_2002  30 non-null     float64
#  11  gdpPercap_2007  30 non-null     float64
# dtypes: float64(12)
# memory usage: 3.0+ KB

# %%
#Getting summary statistics about the dataframe

df.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967
# count       30.000000       30.000000       30.000000       30.000000  \
# mean      5661.057435     6963.012816     8365.486814    10143.823757
# std       3114.060493     3677.950146     4199.193906     4724.983889
# min        973.533195     1353.989176     1709.683679     2172.352423
# 25%       3241.132406     4394.874315     5373.536612     6657.939047
# 50%       5142.469716     6066.721495     7515.733737     9366.067033
# 75%       7236.794919     9597.220820    10931.085348    13277.182058
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987
# count       30.000000       30.000000       30.000000       30.000000  \
# mean     12479.575246    14283.979110    15617.896551    17214.310727
# std       5509.691411     5874.464896     6453.234827     7482.957960
# ...

# %%
#Slicing a column of the dataframe

df["gdpPercap_1952"]
# Out:
# country
# Albania                    1601.056136
# Austria                    6137.076492
# Belgium                    8343.105127
# Bosnia and Herzegovina      973.533195
# Bulgaria                   2444.286648
# Croatia                    3119.236520
# Czech Republic             6876.140250
# Denmark                    9692.385245
# Finland                    6424.519071
# France                     7029.809327
# Germany                    7144.114393
# Greece                     3530.690067
# Hungary                    5263.673816
# Iceland                    7267.688428
# Ireland                    5210.280328
# Italy                      4931.404155
# Montenegro                 2647.585601
# Netherlands                8941.571858
# Norway                    10095.421720
# Poland                     4029.329699
# Portugal                   3068.319867
# Romania                    3144.613186
# Serbia                     3581.459448
# Slovak Republic            5074.659104
# ...

# %%
#Slicing two columns--note the double square brackets

df[["gdpPercap_1952", "gdpPercap_1962"]]
# Out:
#                         gdpPercap_1952  gdpPercap_1962
# country
# Albania                    1601.056136     2312.888958
# Austria                    6137.076492    10750.721110
# Belgium                    8343.105127    10991.206760
# Bosnia and Herzegovina      973.533195     1709.683679
# Bulgaria                   2444.286648     4254.337839
# Croatia                    3119.236520     5477.890018
# Czech Republic             6876.140250    10136.867130
# Denmark                    9692.385245    13583.313510
# Finland                    6424.519071     9371.842561
# France                     7029.809327    10560.485530
# Germany                    7144.114393    12902.462910
# Greece                     3530.690067     6017.190733
# Hungary                    5263.673816     7550.359877
# Iceland                    7267.688428    10350.159060
# Ireland                    5210.280328     6631.597314
# Italy                      4931.404155     8243.582340
# ...

# %%
#Getting a particular cell's value based on column and row headings

df.loc["Belgium", "gdpPercap_1952"]
# Out:
# 8343.105127

# %%
#Slicing a row of a dataframe--note the difference to slicing a column

df.loc["Belgium"]
# Out:
# gdpPercap_1952     8343.105127
# gdpPercap_1957     9714.960623
# gdpPercap_1962    10991.206760
# gdpPercap_1967    13149.041190
# gdpPercap_1972    16672.143560
# gdpPercap_1977    19117.974480
# gdpPercap_1982    20979.845890
# gdpPercap_1987    22525.563080
# gdpPercap_1992    25575.570690
# gdpPercap_1997    27561.196630
# gdpPercap_2002    30485.883750
# gdpPercap_2007    33692.605080
# Name: Belgium, dtype: float64

# %%
#Getting a subset of data using a slice of both rows and columns

df.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972
# country
# Italy           8243.582340    10022.401310    12269.273780
# Montenegro      4649.593785     5907.850937     7778.414017
# Netherlands    12790.849560    15363.251360    18794.745670
# Norway         13450.401510    16361.876470    18965.055510
# Poland          5338.752143     6557.152776     8006.506993

# %%
#Find the minimum value in a particular row

df.loc["Belgium"].min()
# Out:
# 8343.105127

# %%
#Find the minimum value in a particular row

df.loc["Belgium"].max()
# Out:
# 33692.60508

# %%
#Get the mean GDP of the entire dataset

df.mean()
# Out:
# gdpPercap_1952     5661.057435
# gdpPercap_1957     6963.012816
# gdpPercap_1962     8365.486814
# gdpPercap_1967    10143.823757
# gdpPercap_1972    12479.575246
# gdpPercap_1977    14283.979110
# gdpPercap_1982    15617.896551
# gdpPercap_1987    17214.310727
# gdpPercap_1992    17061.568084
# gdpPercap_1997    19076.781802
# gdpPercap_2002    21711.732422
# gdpPercap_2007    25054.481636
# dtype: float64

# %%
#Get the mean value of a particular column

df["gdpPercap_1952"].mean()
# Out:
# 5661.0574347599995

# %%
#Extracting the names of the columns and rows

countries = df.index.values
years = df.columns.values

# %%
print(countries)
print(years)
# Out:
# ['Albania' 'Austria' 'Belgium' 'Bosnia and Herzegovina' 'Bulgaria'
#  'Croatia' 'Czech Republic' 'Denmark' 'Finland' 'France' 'Germany'
#  'Greece' 'Hungary' 'Iceland' 'Ireland' 'Italy' 'Montenegro' 'Netherlands'
#  'Norway' 'Poland' 'Portugal' 'Romania' 'Serbia' 'Slovak Republic'
#  'Slovenia' 'Spain' 'Sweden' 'Switzerland' 'Turkey' 'United Kingdom']
# ['gdpPercap_1952' 'gdpPercap_1957' 'gdpPercap_1962' 'gdpPercap_1967'
#  'gdpPercap_1972' 'gdpPercap_1977' 'gdpPercap_1982' 'gdpPercap_1987'
#  'gdpPercap_1992' 'gdpPercap_1997' 'gdpPercap_2002' 'gdpPercap_2007']
